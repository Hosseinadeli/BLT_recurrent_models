# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
from models.blt import get_blt_model

# model_name = "bl_top2linear"
model_name = "blt"
model = get_blt_model(model_name, num_layers=6, in_channels=3, num_recurrent_steps=10, num_classes=1000)
model
# Out:
# BLTNet(
#   (conv_input): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (maxpool_input): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (norm_0): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (non_lin_0): ReLU(inplace=True)
#   (output_0): Identity()
#   (conn_0_to_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conn_1_to_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm_1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (non_lin_1): ReLU(inplace=True)
#   (output_1): Identity()
#   (conn_0_to_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conn_1_to_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conn_2_to_1): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   (norm_2): GroupNorm(32, 128, eps=1e-05, affine=True)
#   (non_lin_2): ReLU(inplace=True)
# ...

# %%
from models._blt_old import get_blt_model as get_blt_model_old
model_old = get_blt_model_old(model_name, num_layers=6, in_channels=3, times=10, num_classes=1000)
model_old
# Out:
# 56 56 1
# 56 56 1
# 56 56 1
# 56 28 2
# 28 28 1
# 28 28 1
# 28 28 1
# 28 14 2
# 14 14 1
# 14 7 2
# 7 7 1
# blt(
#   (conv_input): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (maxpool_input): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (non_lin_0): ReLU(inplace=True)
#   (norm_0): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (output_0): Identity()
#   (conv_0_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_0_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (non_lin_1): ReLU(inplace=True)
#   (norm_1): GroupNorm(32, 64, eps=1e-05, affine=True)
#   (output_1): Identity()
#   (conv_1_0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_1_1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_1_2): Sequential(
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
sample_input = torch.ones(1, 3, 224, 224)

# %%
model.out_shape
# Out:
# {'0': 56, '1': 56, '2': 28, '3': 28, '4': 14, '5': 7}

# %%
model.forward(sample_input)[-1]
# Out:
# t=1 layer=0, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=1 layer=1, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=2 layer=0, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=2 layer=1, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=2 layer=2, layer_input.shape=torch.Size([1, 128, 28, 28])
# t=3 layer=0, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=3 layer=1, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=3 layer=2, layer_input.shape=torch.Size([1, 128, 28, 28])
# t=3 layer=3, layer_input.shape=torch.Size([1, 128, 28, 28])
# t=4 layer=0, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=4 layer=1, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=4 layer=2, layer_input.shape=torch.Size([1, 128, 28, 28])
# t=4 layer=3, layer_input.shape=torch.Size([1, 128, 28, 28])
# t=4 layer=4, layer_input.shape=torch.Size([1, 256, 14, 14])
# t=5 layer=0, layer_input.shape=torch.Size([1, 64, 56, 56])
# t=5 layer=1, layer_input.shape=torch.Size([1, 64, 56, 56])
# ...

# %%
model_old.forward(sample_input)[-1]
# Out:
# tensor([[ 1.8895e-01, -2.8804e-01, -1.0577e-01, -4.9171e-02,  7.7972e-01,
#          -7.1076e-01, -8.4931e-02, -5.1573e-01,  2.5978e-01, -4.6523e-01,
#           3.7723e-01, -7.0086e-02, -5.7835e-01, -4.3824e-01, -9.8793e-02,
#          -8.9847e-01, -3.8300e-01,  2.9527e-01,  2.9844e-01, -4.7638e-01,
#           1.4349e-02,  3.3939e-01,  2.6144e-02,  9.9394e-02, -6.8386e-01,
#           5.2684e-01,  5.8581e-01, -6.2393e-01,  1.1106e+00, -3.1929e-01,
#           7.5869e-01,  5.7496e-01, -4.3407e-01,  2.3814e-02, -6.5700e-01,
#           4.3309e-01, -4.8718e-01,  2.3003e-02, -7.1904e-01, -1.2547e-01,
#           2.7421e-02, -2.9790e-01, -2.0173e-01, -4.1925e-01,  3.2084e-01,
#           2.8734e-02, -2.6462e-01,  1.2463e-01, -1.0935e-01,  7.0735e-03,
#          -4.3102e-01,  6.4911e-01,  5.3982e-02,  2.1902e-01,  2.2179e-01,
#          -1.6173e-01, -2.1271e-01, -2.3606e-01,  1.5139e-01, -2.9930e-01,
#           3.2701e-01, -6.5765e-02, -2.8001e-01,  1.4716e+00, -1.6239e-02,
# ...
